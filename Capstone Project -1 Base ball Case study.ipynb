# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib .pyplot as plt
import warnings
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.rename(columns={'W':'Wins',
                   'R':'Runs Scored',
                   'AB':'At Bat',
                   'H':'Hits',
                   '2B':'Doubles',
                   '3B':'Triples',
                   'HR':'Home Runs',
                   'BB':'Base on Ball',
                   'SO':'Strike Outs',
                   'SB':'Stole Base',
                   'RA':'Runs Average',
                   'ER':'Earned Run',
                   'ERA':'Earned Run Average',
                   'CG':'Complete Game',
                   'SHO':'Shut outs',
                   'SV':'Saves',
                   'E':'Errors',
                  }, inplace =True)
df.head()
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  Base on Ball  \
# 0    95          724    5575  1497      300       42        139           383
# 1    83          696    5467  1349      277       44        156           439
# 2    81          669    5439  1395      303       29        141           533
# 3    76          622    5533  1381      260       27        136           404
# 4    74          689    5605  1515      289       49        151           455
#
#    Strike Outs  Stole Base  Runs Average  Earned Run  Earned Run Average  \
# 0          973         104           641         601                3.73
# 1         1264          70           700         653                4.07
# 2         1157          86           640         584                3.67
# 3         1231          68           701         643                3.98
# 4         1259          83           803         746                4.64
#
#    Complete Game  Shut outs  Saves  Errors
# ...

# %%
df.isnull().sum()
# Out:
# Wins                  0
# Runs Scored           0
# At Bat                0
# Hits                  0
# Doubles               0
# Triples               0
# Home Runs             0
# Base on Ball          0
# Strike Outs           0
# Stole Base            0
# Runs Average          0
# Earned Run            0
# Earned Run Average    0
# Complete Game         0
# Shut outs             0
# Saves                 0
# Errors                0
# dtype: int64

# %%
df.describe()
# Out:
#              Wins  Runs Scored       At Bat         Hits     Doubles  \
# count   30.000000    30.000000    30.000000    30.000000   30.000000
# mean    80.966667   688.233333  5516.266667  1403.533333  274.733333
# std     10.453455    58.761754    70.467372    57.140923   18.095405
# min     63.000000   573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000   651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000   689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000   718.250000  5570.000000  1451.500000  288.750000
# max    100.000000   891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home Runs  Base on Ball  Strike Outs  Stole Base  \
# count  30.000000   30.000000     30.000000     30.00000   30.000000
# mean   31.300000  163.633333    469.100000   1248.20000   83.500000
# std    10.452355   31.823309     57.053725    103.75947   22.815225
# min    13.000000  100.000000    375.000000    973.00000   44.000000
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
#as per above data it seems right skewed feature except Eun scored and Eorror , 30 lines in each columns meane complete data

# %%
plt.figure(figsize=(25,25), facecolor='skyblue')
index=1
for column in df:
    if index<=17:
        ax=plt.subplot(5,4,index)
        sns.boxplot(df[column], palette='coolwarm')
        plt.xlabel(column , fontsize=15)
    index+=1
plt.show()

# %%
# outlier in Error, Saves, shut out,Earned run average and run scored , we need remove these outliers

# %%
from scipy.stats import zscore

z_score=np.abs(zscore(df))
threshold=3

df1=df[(z_score<threshold).all(axis=1)]

# %%
print("revised data",df1.shape)
# Out:
# revised data (29, 17)

# %%
#3% data loss

print("loss in %",((1/30)*100,'%'))
# Out:
# loss in % (3.3333333333333335, '%')

# %%
df1.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.783772
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Ball          0.151193
# Strike Outs          -0.233815
# Stole Base            0.494966
# Runs Average          0.018155
# Earned Run            0.018461
# Earned Run Average    0.016693
# Complete Game         0.854980
# Shut outs             0.526943
# Saves                 0.627480
# Errors                0.840271
# dtype: float64

# %%
# hits,complete game,shut outs,saves,error are+ve skewed, we need to transform for removing skewness

# %%
df1.columns
# Out:
# Index(['Wins', 'Runs Scored', 'At Bat', 'Hits', 'Doubles', 'Triples',
#        'Home Runs', 'Base on Ball', 'Strike Outs', 'Stole Base',
#        'Runs Average', 'Earned Run', 'Earned Run Average', 'Complete Game',
#        'Shut outs', 'Saves', 'Errors'],
#       dtype='object')

# %%
column_name=['Hits','Complete Game','Shut outs','Saves','Errors']

df1[column_name]= np.log1p(df[column_name])

# %%
sns.histplot(df[column_name], kde=True)
plt.show()

# %%
df1.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.738455
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Ball          0.151193
# Strike Outs          -0.233815
# Stole Base            0.494966
# Runs Average          0.018155
# Earned Run            0.018461
# Earned Run Average    0.016693
# Complete Game        -0.275681
# Shut outs            -0.598073
# Saves                 0.109983
# Errors                0.586101
# dtype: float64

# %%
# now all columns in range of -0.5 to 0.5

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(),linewidth=0.1,fmt='0.3f',annot=True)
# Out:
# <Axes: >

# %%
# as per above heatamp Runs average,Earned run and Earned run average are +ve correlation and -ve correlation with wins

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['features']=df1.columns
vif
# Out:
#               VIF            features
# 0     1251.442420                Wins
# 1     2617.409490         Runs Scored
# 2   125947.045153              At Bat
# 3   129711.729334                Hits
# 4      994.113778             Doubles
# 5       33.608740             Triples
# 6      205.509670           Home Runs
# 7      258.650713        Base on Ball
# 8      411.701884         Strike Outs
# 9       27.235606          Stole Base
# 10   16169.122391        Runs Average
# 11  160471.082444          Earned Run
# 12  133393.201582  Earned Run Average
# 13      15.004346       Complete Game
# 14     143.341584           Shut outs
# 15    4061.198152               Saves
# 16    1878.292300              Errors

# %%
# data is not scaled , if we see that same 3 columns are higly correlated

# %%
X=df1.iloc[:,1:-1]
y=df1.iloc[:,0]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
#implementing principal Component analysis helps the multicollinearity

# %%
from sklearn.decomposition import PCA

pca=PCA()
X_pca=pca.fit_transform(X_scaled)

# %%
X_= pd.DataFrame(X_pca, columns=np.arange(15))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data= pd.DataFrame()
vif_data["features list"]=X.columns
vif_data["VIF values"]=[variance_inflation_factor(X_.values,i)
                       for i in range (len(X_.columns))]

vif_data
# Out:
#          features list  VIF values
# 0          Runs Scored         1.0
# 1               At Bat         1.0
# 2                 Hits         1.0
# 3              Doubles         1.0
# 4              Triples         1.0
# 5            Home Runs         1.0
# 6         Base on Ball         1.0
# 7          Strike Outs         1.0
# 8           Stole Base         1.0
# 9         Runs Average         1.0
# 10          Earned Run         1.0
# 11  Earned Run Average         1.0
# 12       Complete Game         1.0
# 13           Shut outs         1.0
# 14               Saves         1.0

# %%
X_.skew()
# Out:
# 0     0.072786
# 1    -0.103351
# 2     0.093333
# 3    -0.183638
# 4     0.231328
# 5     0.113868
# 6     0.695706
# 7     0.041014
# 8     0.147935
# 9     0.742452
# 10    0.776093
# 11    0.079855
# 12    0.234348
# 13    0.344537
# 14    0.341381
# dtype: float64

# %%
# Machine learning Model

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
# linear Regression

from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
maxR2_score=0
maxRS=0
for i in range(0,200):
    X_train,X_test,y_train,y_test=train_test_split(X_,y, random_state=i, test_size=.2)
    lr.fit (X_train,y_train)
    y_pred=lr.predict(X_test)
    R2=r2_score(y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i

print('R2 score is ', (maxR2_score)*100,'\n random state', maxRS)
# Out:
# R2 score is  95.16954924533552
#  random state 160

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print('Mean absolute error', mean_absolute_error(y_test,y_pred))
print('Mean squared error', mean_squared_error(y_test,y_pred))
print('Root mean squared error', np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean absolute error 3.0993203087985464
# Mean squared error 11.322422054473584
# Root mean squared error 3.3648806894856738

# %%
from sklearn.linear_model import LogisticRegression

# %%
lor=LogisticRegression()

# %%
maxR2_score=0
maxRS=0
for i in range(0,200):
    X_train,X_test,y_train,y_test=train_test_split(X_,y, random_state=i, test_size=.2)
    lor.fit (X_train,y_train)
    y_pred1=lor.predict(X_test)
    R2=r2_score(y_test,y_pred1)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i

print('R2 score is ', (maxR2_score)*100,'\n random state', maxRS)
# Out:
# R2 score is  92.44296577946768
#  random state 64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
maxR2_score=0
maxRS=0
for i in range(0,200):
    X_train,X_test,y_train,y_test=train_test_split(X_,y, random_state=i, test_size=.2)
    dtc.fit (X_train,y_train)
    y_pred2=dtc.predict(X_test)
    R2=r2_score(y_test,y_pred2)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i

print('R2 score is ', (maxR2_score)*100,'\n random state', maxRS)
# Out:
# R2 score is  75.03024437454634
#  random state 97

# %%
# Hyper parameter tunning

from sklearn.model_selection import GridSearchCV
lr=LinearRegression()
param={'fit_intercept': [True, False],
            'copy_X'  : [True, False],
          'positive'  : [True, False],
           'n_jobs'   : [-2,-1,-1]
      }

# %%
gsv=GridSearchCV(lr,param,cv=5)

# %%
gsv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [-2, -1, -1],
#                          'positive': [True, False]})

# %%
gsv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -2, 'positive': False}

# %%
model= LinearRegression( fit_intercept=True, copy_X=True, n_jobs=-2, positive=False)

# %%
model.fit(X_train,y_train)
pred=model.predict(X_test)
print('R2 score', r2_score(y_test,pred))
print('Mean absolute error',mean_absolute_error(y_test,pred))
print('Mean Squared error', mean_squared_error(y_test,pred))
print ('Root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score 0.8594942454460361
# Mean absolute error 3.0993203087985464
# Mean Squared error 11.322422054473584
# Root mean squared error 3.3648806894856738

# %%
import joblib
joblib.dump(model,'Baseball_model.pkl')
# Out:
# ['Baseball_model.pkl']
